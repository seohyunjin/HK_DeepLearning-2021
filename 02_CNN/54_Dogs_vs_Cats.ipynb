# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 전부를 이용한 개, 고양이 구분
#      https://www.kaggle.com/c/dogs-vs-cats/data
#
# Dog Image: 12,500개, Cat Image: 12,500개, 총 25,000개

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train'

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
## Definition to load all our dog images
def load_dogs():
    print('Loading all dog images\n')
    dog_path = os.path.join(path, 'dog*')
    for dog_img in glob(dog_path):
        dog = cv2.imread(dog_img)
        dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
        dog = cv2.resize(dog, (ROW, COL))
        dog = image.img_to_array(dog)
        dogs.append(dog)
    print('All dog images loaded')

# %%
## Definition to load all our cat images
def load_cats():
    print('Loading all cat images\n')
    cat_path = os.path.join(path, 'cat*')
    for cat_img in glob(cat_path):
        cat = cv2.imread(cat_img)
        cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
        cat = cv2.resize(cat, (ROW, COL))
        cat = image.img_to_array(cat)
        cats.append(cat)
    print('All cat images loaded')

# %%
## in case we want to see if our images was saved correctly in arrays we can use those codes
def show_dogs():
    plt.figure(figsize=(12,4))    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(dogs))
        plt.imshow(img, cmap=plt.get_cmap('gray'))
        
        plt.axis('off')
        plt.title(f'Supposed to be a {classes[0]}')        
    plt.show()

# %%
def show_cats():
    plt.figure(figsize=(12,4))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(cats))
        plt.imshow(img, cmap=plt.get_cmap('gray'))

        plt.axis('off')
        plt.title(f'Supposed to be a {classes[1]}')
    plt.show()

# %%
load_dogs()
# Out:
# Loading all dog images
#
# All dog images loaded

# %%
load_cats()
# Out:
# Loading all cat images
#
# All cat images loaded

# %%
classes = ['dog', 'cat']

# %%
show_dogs()

# %%
show_cats()

# %%
## just change the labels for 0 and 1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X = np.concatenate((dogs, cats), axis=0)
y = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X.shape, y.shape
# Out:
# ((25000, 96, 96, 1), (25000,))

# %%
IMG_CHANNEL = 1
BATCH_SIZE = 128
N_EPOCH = 30
VERBOSE = 2
VALIDAION_SPLIT = 0.2
OPTIM = Adam()
N_CLASSES = len(classes)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=seed
)

# %%
## One-Hot Encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, N_CLASSES)
y_test = to_categorical(y_test, N_CLASSES)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, IMG_CHANNEL), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(N_CLASSES, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=OPTIM, metrics=['accuracy'])

# %%
## to save checkpoint to use latter
modelpath = 'model/dogs_vs_cats_redux_checkpoint.h5'
checkpoint = ModelCheckpoint(filepath=modelpath, save_best_only=True, verbose=1)

# %%
history = model.fit(X_train, y_train, 
                    batch_size=BATCH_SIZE, epochs=N_EPOCH, 
                    validation_split=VALIDAION_SPLIT,
                    verbose=VERBOSE, callbacks=[checkpoint])
# Out:
# Epoch 1/30
#
# Epoch 00001: val_loss improved from inf to 0.61772, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 234s - loss: 0.6816 - accuracy: 0.5714 - val_loss: 0.6177 - val_accuracy: 0.6518
# Epoch 2/30
#
# Epoch 00002: val_loss improved from 0.61772 to 0.55613, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 239s - loss: 0.5874 - accuracy: 0.6826 - val_loss: 0.5561 - val_accuracy: 0.7130
# Epoch 3/30
#
# Epoch 00003: val_loss improved from 0.55613 to 0.54609, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 233s - loss: 0.5452 - accuracy: 0.7216 - val_loss: 0.5461 - val_accuracy: 0.7362
# Epoch 4/30
#
# Epoch 00004: val_loss improved from 0.54609 to 0.48239, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 222s - loss: 0.4946 - accuracy: 0.7598 - val_loss: 0.4824 - val_accuracy: 0.7738
# Epoch 5/30
#
# Epoch 00005: val_loss improved from 0.48239 to 0.43774, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 230s - loss: 0.4554 - accuracy: 0.7836 - val_loss: 0.4377 - val_accuracy: 0.7960
# Epoch 6/30
#
# Epoch 00006: val_loss improved from 0.43774 to 0.41000, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 215s - loss: 0.4176 - accuracy: 0.8062 - val_loss: 0.4100 - val_accuracy: 0.8160
# Epoch 7/30
#
# Epoch 00007: val_loss improved from 0.41000 to 0.40305, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 222s - loss: 0.3862 - accuracy: 0.8248 - val_loss: 0.4031 - val_accuracy: 0.8200
# Epoch 8/30
#
# Epoch 00008: val_loss improved from 0.40305 to 0.39490, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 249s - loss: 0.3449 - accuracy: 0.8491 - val_loss: 0.3949 - val_accuracy: 0.8248
# Epoch 9/30
#
# Epoch 00009: val_loss improved from 0.39490 to 0.38038, saving model to model\dogs_vs_cats_redux_checkpoint.h5
# 125/125 - 224s - loss: 0.3053 - accuracy: 0.8679 - val_loss: 0.3804 - val_accuracy: 0.8313
# Epoch 10/30
#
# Epoch 00010: val_loss did not improve from 0.38038
# 125/125 - 222s - loss: 0.2642 - accuracy: 0.8888 - val_loss: 0.3926 - val_accuracy: 0.8353
# Epoch 11/30
#
# Epoch 00011: val_loss did not improve from 0.38038
# 125/125 - 225s - loss: 0.2180 - accuracy: 0.9094 - val_loss: 0.3923 - val_accuracy: 0.8405
# Epoch 12/30
#
# Epoch 00012: val_loss did not improve from 0.38038
# 125/125 - 227s - loss: 0.1836 - accuracy: 0.9268 - val_loss: 0.4206 - val_accuracy: 0.8455
# Epoch 13/30
#
# Epoch 00013: val_loss did not improve from 0.38038
# 125/125 - 227s - loss: 0.1446 - accuracy: 0.9452 - val_loss: 0.4361 - val_accuracy: 0.8415
# Epoch 14/30
#
# Epoch 00014: val_loss did not improve from 0.38038
# 125/125 - 222s - loss: 0.1216 - accuracy: 0.9538 - val_loss: 0.4944 - val_accuracy: 0.8462
# Epoch 15/30
#
# Epoch 00015: val_loss did not improve from 0.38038
# 125/125 - 233s - loss: 0.0988 - accuracy: 0.9621 - val_loss: 0.5023 - val_accuracy: 0.8285
# Epoch 16/30
#
# Epoch 00016: val_loss did not improve from 0.38038
# 125/125 - 229s - loss: 0.0863 - accuracy: 0.9698 - val_loss: 0.4924 - val_accuracy: 0.8438
# Epoch 17/30
#
# Epoch 00017: val_loss did not improve from 0.38038
# 125/125 - 214s - loss: 0.0678 - accuracy: 0.9766 - val_loss: 0.5536 - val_accuracy: 0.8395
# Epoch 18/30
#
# Epoch 00018: val_loss did not improve from 0.38038
# 125/125 - 219s - loss: 0.0622 - accuracy: 0.9778 - val_loss: 0.6042 - val_accuracy: 0.8462
# Epoch 19/30
#
# Epoch 00019: val_loss did not improve from 0.38038
# 125/125 - 262s - loss: 0.0543 - accuracy: 0.9816 - val_loss: 0.6184 - val_accuracy: 0.8410
# Epoch 20/30
#
# Epoch 00020: val_loss did not improve from 0.38038
# 125/125 - 268s - loss: 0.0476 - accuracy: 0.9834 - val_loss: 0.6251 - val_accuracy: 0.8475
# Epoch 21/30
#
# Epoch 00021: val_loss did not improve from 0.38038
# 125/125 - 229s - loss: 0.0561 - accuracy: 0.9807 - val_loss: 0.6184 - val_accuracy: 0.8490
# Epoch 22/30
#
# Epoch 00022: val_loss did not improve from 0.38038
# 125/125 - 234s - loss: 0.0471 - accuracy: 0.9844 - val_loss: 0.6675 - val_accuracy: 0.8363
# Epoch 23/30
#
# Epoch 00023: val_loss did not improve from 0.38038
# 125/125 - 238s - loss: 0.0424 - accuracy: 0.9866 - val_loss: 0.6378 - val_accuracy: 0.8395
# Epoch 24/30
#
# Epoch 00024: val_loss did not improve from 0.38038
# 125/125 - 248s - loss: 0.0381 - accuracy: 0.9864 - val_loss: 0.6194 - val_accuracy: 0.8407
# Epoch 25/30
#
# Epoch 00025: val_loss did not improve from 0.38038
# 125/125 - 245s - loss: 0.0353 - accuracy: 0.9892 - val_loss: 0.6168 - val_accuracy: 0.8363
# Epoch 26/30
#
# Epoch 00026: val_loss did not improve from 0.38038
# 125/125 - 262s - loss: 0.0353 - accuracy: 0.9888 - val_loss: 0.6639 - val_accuracy: 0.8403
# Epoch 27/30
#
# Epoch 00027: val_loss did not improve from 0.38038
# 125/125 - 263s - loss: 0.0336 - accuracy: 0.9898 - val_loss: 0.6524 - val_accuracy: 0.8363
# Epoch 28/30
#
# Epoch 00028: val_loss did not improve from 0.38038
# 125/125 - 262s - loss: 0.0276 - accuracy: 0.9900 - val_loss: 0.7332 - val_accuracy: 0.8453
# Epoch 29/30
#
# Epoch 00029: val_loss did not improve from 0.38038
# 125/125 - 262s - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.7661 - val_accuracy: 0.8288
# Epoch 30/30
#
# Epoch 00030: val_loss did not improve from 0.38038
# 125/125 - 267s - loss: 0.0272 - accuracy: 0.9915 - val_loss: 0.7132 - val_accuracy: 0.8432

# %%
acc = model.evaluate(X_test, y_test, verbose=2)[1]
print('MODEL ACCURACY: %.5f' % acc)
# Out:
# 157/157 - 18s - loss: 0.7372 - accuracy: 0.8468
# MODEL ACCURACY: 0.84680

# %%
from tensorflow.keras.models import load_model
best_model = load_model(modelpath)
acc = best_model.evaluate(X_test, y_test, verbose=2)[1]
print('Best model accuracy: %.5f' % acc)
# Out:
# 157/157 - 17s - loss: 0.3788 - accuracy: 0.8322
# Best model accuracy: 0.83220

# %%
# 검증셋
y_vloss = history.history['val_loss']
y_vacc = history.history['val_accuracy']

# 학습셋
y_loss = history.history['loss']
y_acc = history.history['accuracy']

# %%
x_len = np.arange(1, len(y_loss)+1)
fig, ax0 = plt.subplots(figsize=(10,8))
ax1 = ax0.twinx()
ax0.plot(x_len, y_loss, c="blue", label='train set loss')
ax0.plot(x_len, y_vloss, c="red", label='valid set loss')
ax0.set_ylabel('loss')
ax1.plot(x_len, y_acc, c="darkgreen", label='train set acc')
ax1.plot(x_len, y_vacc, c="magenta", label='valid set acc')
ax1.set_ylabel('accuracy')
ax0.set_xlabel('epoch')
ax0.legend(loc='lower center')
ax1.legend(loc='upper center')
plt.grid()
plt.show()
